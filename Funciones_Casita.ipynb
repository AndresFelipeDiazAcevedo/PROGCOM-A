# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresFelipeDiazAcevedo/PROGCOM-A/blob/main/Funciones_Casita.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def pared_derecha(a):
  print("Pared derecha pintada con franjas azules en diagonal")
pared_derecha(1)
# Out:
# Pared derecha pintada con franjas azules en diagonal

# %%
def pared_izquierda(a):
  print("Pared derecha pintada con franjas azules en vertical \n")
  print("Flores pintadas arriba y abajo en las partes blancas")
pared_izquierda(1)
# Out:
# Pared derecha pintada con franjas azules en vertical
#
# Flores pintadas arriba y abajo en las partes blancas

# %%
def techo(a):
  print("techo cafe (como si fuese teja)")
techo(1)
# Out:
# techo cafe (como si fuese teja)

# %%
def fachada_frontal(a):
  print("Letrero principal que dice FLORISTERIA de color en azul y flores en la parte superior")
  print("Puerta individual puntada con puntos azules en fondo blanco")
  print("triangulo superior que conecta con el techo pintado de multicolor para dar mas color ")
fachada_frontal(1)
# Out:
# Letrero principal que dice FLORISTERIA de color en azul y flores en la parte superior
# Puerta individual puntada con puntos azules en fondo blanco
# triangulo superior que conecta con el techo pintado de multicolor para dar mas color

# %%
def fachada_atras(a):
    print("Fachada pintada de verde con enredaderas a sus 2 costados con una ventana en la parte de la mitad que permite ver las flores de adentro")
fachada_atras(1)
# Out:
# Fachada pintada de verde con enredaderas a sus 2 costados con una ventana en la parte de la mitad que permite ver las flores de adentro
