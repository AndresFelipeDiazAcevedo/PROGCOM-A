# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresFelipeDiazAcevedo/PROGCOM-A/blob/main/Clase_10_POO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Casa:
  """
  Construir el constructor
  argumentos:
    color(str): color de la casa
    numero_habitaciones(int): el numero de habitaciones de la casa
    numero_baños(int): el numero de baños en la casa
    estacionamiento(bool): si tiene estacionamiento o no
    tiene_patio(bool): si tiene patio o no
  """
  def __init__(self, color, numero_habitaciones, numero_baños, estacionamiento, tiene_patio):
    self.color = color
    self.numero_habitaciones = numero_habitaciones
    self.numero_baños = numero_baños
    self.estacionamiento = estacionamiento
    self.tiene_patio = tiene_patio

  def descripcion(self):
    #Describir la casa
    descripcion=f"la casa es de color {self.color}, tiene {self.numero_habitaciones} habitaciones, {self.numero_baños} baños"
    if self.estacionamiento:
      descripcion += "\nTiene estacionamiento"

    if self.tiene_patio:
      descripcion += "\nTiene patio"
    return descripcion

  def pintar(self,nuevo_color):
    self.color=nuevo_color
    print(f"la casa ha sido pintada de color {self.color}")

# %%
mi_casa=Casa("negra", 4, 2, True, True)
type(mi_casa)
# Out:
# __main__.Casa

# %%
print(mi_casa.descripcion())
# Out:
# la casa es de color negra, tiene 4 habitaciones, 2 baños
# Tiene estacionamiento
# Tiene patio

# %%
mi_casa.tiene_patio=False
print(mi_casa.descripcion())
# Out:
# la casa es de color negra, tiene 4 habitaciones, 2 baños
# Tiene estacionamiento

# %%
mi_casa.pintar("azul")
print(mi_casa.descripcion())
# Out:
# la casa ha sido pintada de color azul
# la casa es de color azul, tiene 4 habitaciones, 2 baños
# Tiene estacionamiento

# %%
class Floristeria(Casa):
  """
  Constructor de la floristeria
  Argumentos:
    color_paredes_laterales(str): color de las paredes laterales
    color_fachada_frontal(str): color fachada frontal
    color_fachada_trasera(str): color fachada de atras
    numero_habitaciones(int): el numero de habitaciones de la Floristeria
    numero_baños(int): el numero de baños en la floristeria
    nombre_floristeria: nombre de la floristeria
    tipos_flores(list): Lista de flores
  """

  def __init__(self, color , numero_habitaciones, numero_baños, estacionamiento, tiene_patio,color_paredes_laterales, color_fachada_frontal, color_fachada_trasera, nombre_floristeria, tipos_flores,):
    super().__init__(color, numero_habitaciones, numero_baños,False,False)
    self.color_paredes_laterales = color_paredes_laterales
    self.color_fachada_frontal = color_fachada_frontal
    self.color_fachada_trasera = color_fachada_trasera
    self.nombre_floristeria = nombre_floristeria
    self.tipos_flores = tipos_flores

# %%
mi_floristeria=Floristeria( "ninguno", 1, 1,True, True, "fanjas azules y blancas", "blanca", "verde", "FLORISTEIA", ["petunia", "rosa", "girasol"])
mi_floristeria.descripcion()
# Out:
# 'la casa es de color ninguno, tiene 1 habitaciones, 1 baños'

# %%
class Concurso():
  """
  Atributos
    Mensaje: mensaje a decodificar
    Metodos: codificar
    Metodo decodificar
    Vocal: 2 a la derecha U--> E
    Tilde: 2 a la izquierda Ó--> É
    Consonante: 1 a la izquierda D--> C
    GAKI ---> HOLA
  """
