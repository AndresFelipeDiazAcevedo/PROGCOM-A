# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresFelipeDiazAcevedo/PROGCOM-A/blob/main/Clase_3_Funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #FUNCIONES
# Copiado dinamico<p>
# Dio nacimiento a un nuevo paradigma de programacion llamado programacion modular
# Forma general de programar funciones
#
# ```
# def  (nombre_de_funcion)(p,p2,p3,p4 ....):
#   donde p son parametros
# ```
#
# 1. list()
# 2. len()
# 3. print()
# 4. append()#metodo
# 5. input()
# 6. int()
#
# ## Tipos de funciones
# 1. sin parametros, sin retorno
# 2. sin parametros, con retorno
# 3. con parametros, sin retorno
# 4. con parametros, con retorno

# %%
def cajero():
  print("Bienvenid a DaviUNAB")
  print("Estas son las operaciones que puede realizar:")
  print("1. Retirar\n2. Transferencia\n3. Denunciar\n4. Operacion sin tarjeta")

# %%
cajero()
# Out:
# Bienvenid a DaviUNAB
# Estas son las operaciones que puede realizar:
# 1. Retirar
# 2. Transferencia
# 3. Denunciar
# 4. Operacion sin tarjeta

# %% [markdown]
# ###2. sin parametros, con retorno

# %%
def cajero2():
  print("Bienvenid a DaviUNAB")
  print("Estas son las operaciones que puede realizar:")
  print("1. Retirar\n2. Transferencia\n3. Denunciar\n4. Operacion sin tarjeta")
  rta=input("Ingrese una opcion: ") #Variable local
  return rta #Convierte las variables locales en globales

# %%
rta=cajero2()
# Out:
# Bienvenid a DaviUNAB
# Estas son las operaciones que puede realizar:
# 1. Retirar
# 2. Transferencia
# 3. Denunciar
# 4. Operacion sin tarjeta
# Ingrese una opcion: 2

# %%
type(rta)
# Out:
# str

# %% [markdown]
# ##3. con parametros, sin retorno

# %%
#EJEMPLO: area de un rectangulo
def ab(u,du):
  print(f"El area de un rectangulo de base {u} y altura {du} es {u*du}")

# %%
a=ab(2,3)
# Out:
# El area de un rectangulo de base 2 y altura 3 es 6

# %%
print(a)
# Out:
# None

# %% [markdown]
# ###4. con parametros, con retorno

# %%
#EJEMPLO: area de un rectangulo
def area_rectangulo(u,du):
  return f"El area de un rectangulo de base {u} y altura {du} es {u*du}"

# %%
a=area_rectangulo(10,15)

# %%
print(a)
# Out:
# El area de un rectangulo de base 10 y altura 15 es 150

# %% [markdown]
# ##Funciones anonimas o lambda
# 1. Siempre usan parametros
# 2. Siempre dan retorno
# 3. no tienen nombre --> anonimas
# 4. **Se puede emplear n parametros, pero solo ejecuta 1 linea de codigo**
#
# ### Definicion
#
# ```
# variable=lambda (p,p1,p2...pn):operacion
# ```

# %%
#calcular area triangulo
area_triangulo=lambda a,b: a*b/2

# %%
area_triangulo(15,10)
# Out:
# 75.0

# %%
area_circulo=lambda a: (3.14)*a**2

# %%
area_circulo(3)
# Out:
# 28.26

# %%
edad_mayor=lambda a,b,c: max(a,b,c)

# %%
edad_mayor(7,8,10)
# Out:
# 10

# %%
edad_mayor_terniario=lambda a,b,c: a if a>b and a>c else b if  b>c else c

# %%
edad_mayor_terniario(15,17,2)
# Out:
# 17
